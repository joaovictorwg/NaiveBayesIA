# %% [markdown]
# ### Imports

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load datasets

# %%
iris = datasets.load_iris()

iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['class'] = iris.target
iris_df['class'] = iris_df['class'].map(dict(enumerate(iris.target_names)))

print(iris_df.to_string(index=True))
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)       class
# 0                  5.1               3.5                1.4               0.2      setosa
# 1                  4.9               3.0                1.4               0.2      setosa
# 2                  4.7               3.2                1.3               0.2      setosa
# 3                  4.6               3.1                1.5               0.2      setosa
# 4                  5.0               3.6                1.4               0.2      setosa
# 5                  5.4               3.9                1.7               0.4      setosa
# 6                  4.6               3.4                1.4               0.3      setosa
# 7                  5.0               3.4                1.5               0.2      setosa
# 8                  4.4               2.9                1.4               0.2      setosa
# ...

# %% [markdown]
# ### Plot Dataset

# %%
# Carregar o conjunto de dados Iris
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Calcular a matriz de correlação entre as features e a classe
corr_matrix = df.corrwith(df['target'])

# Plotar a correlação
plt.figure(figsize=(12, 6))
plt.bar(corr_matrix.index, corr_matrix.values)
plt.xlabel('Features')
plt.ylabel('Correlation with Target')
plt.title('Correlation between Features and Target Class')
plt.show()

# %% [markdown]
# ### Calcular Média e Desvio Padrão

# %%
def calcular_likelihood(df, y, label):
    likelihoods = {}
    for feat_name in df.columns:
        feat_val = df[feat_name]
        df_filtered = df[df[Y] == label]
        #MEDIA
        mean = sum(df_filtered[feat_name]) / len(df_filtered[feat_name])
        #DESVIO PADRAO
        std = df_filtered[feat_name].std()
        #PROBABILIDADE DE X DADO Y
        p_x_given_y = (1 / (np.sqrt(2 * np.pi) * std)) * np.exp(-((feat_val - mean) ** 2 / (2 * std ** 2)))
        #ARMAZENAR LIKELIHOODS
        likelihoods[feat_name] = p_x_given_y
    return likelihoods

sepal_length = iris.data[:, 0]

#MEDIA
#media_sepal_length = sum(sepal_length) / len(sepal_length)
#VARIANCIA E DESVIO PADRAO
#variancia_sepal_length = sum([(x - media_sepal_length) ** 2 for x in sepal_length]) / (len(sepal_length) - 1)
#dp_sepal_length = (variancia_sepal_length**2)**0.5

prob_x_dado_y = (1 / (np.sqrt(2 * np.pi) * dp_sepal_length**2)) * np.exp(-(sepal_length - media_sepal_length)**2 / 2 * dp_sepal_length ** 2)

print(f'Média: {media_sepal_length}\nVariância: {variancia_sepal_length}\nDesvío Padrão: {dp_sepal_length}')
print(f'Probabilidade de um X dado um Y: {prob_x_dado_y}')
# Out:
# Média: 5.843333333333335
# Variância: 0.6856935123042505
# Desvío Padrão: 0.6856935123042505
# Probabilidade de um X dado um Y: [0.74513793 0.68832864 0.62400378 0.5899565  0.71785582 0.81018336
#  0.5899565  0.71785582 0.51994773 0.68832864 0.81018336 0.65692002
#  0.65692002 0.48469285 0.84812188 0.84440822 0.81018336 0.74513793
#  0.84440822 0.74513793 0.81018336 0.74513793 0.5899565  0.74513793
#  0.65692002 0.71785582 0.71785582 0.76982882 0.76982882 0.62400378
#  0.65692002 0.81018336 0.76982882 0.82530595 0.68832864 0.71785582
#  0.82530595 0.68832864 0.51994773 0.74513793 0.71785582 0.5551506
#  0.51994773 0.71785582 0.74513793 0.65692002 0.74513793 0.5899565
#  0.79160717 0.71785582 0.61952129 0.78888244 0.65261008 0.82530595
#  0.76669827 0.84440822 0.80790101 0.68832864 0.7416427  0.76982882
#  0.71785582 0.84785608 0.84361455 0.83545688 0.83676728 0.71404079
#  0.83676728 0.84812188 0.82349709 0.83676728 0.84785608 0.83545688
# ...

# %%
feat = list(df.columns)
    df = df[df[Y]==label]
    mean, std = df[feat_name].mean(), df[feat_name].std()
    p_x_given_y = (1 / (np.sqrt(2 * np.pi) * std)) *  np.exp(-((feat_val-mean)**2 / (2 * std**2 )))
    return p_x_given_y
